# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns

# Configure Visualization Defaults
# %matplotlib inline
pylab.rcParams['figure.figsize'] = 12,8

# %%
train = pd.read_csv('data/training_set_VU_DM.csv',nrows=1000)

# %%
train.info(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 54 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   srch_id                      1000 non-null   int64
#  1   date_time                    1000 non-null   object
#  2   site_id                      1000 non-null   int64
#  3   visitor_location_country_id  1000 non-null   int64
#  4   visitor_hist_starrating      64 non-null     float64
#  5   visitor_hist_adr_usd         64 non-null     float64
#  6   prop_country_id              1000 non-null   int64
#  7   prop_id                      1000 non-null   int64
#  8   prop_starrating              1000 non-null   int64
#  9   prop_review_score            999 non-null    float64
#  10  prop_brand_bool              1000 non-null   int64
#  11  prop_location_score1         1000 non-null   float64
#  12  prop_location_score2         757 non-null    float64
#  13  prop_log_historical_price    1000 non-null   float64
#  14  position                     1000 non-null   int64
#  15  price_usd                    1000 non-null   float64
#  16  promotion_flag               1000 non-null   int64
#  17  srch_destination_id          1000 non-null   int64
#  18  srch_length_of_stay          1000 non-null   int64
#  19  srch_booking_window          1000 non-null   int64
#  20  srch_adults_count            1000 non-null   int64
#  21  srch_children_count          1000 non-null   int64
#  22  srch_room_count              1000 non-null   int64
#  23  srch_saturday_night_bool     1000 non-null   int64
#  24  srch_query_affinity_score    60 non-null     float64
#  25  orig_destination_distance    645 non-null    float64
#  26  random_bool                  1000 non-null   int64
#  27  comp1_rate                   0 non-null      float64
#  28  comp1_inv                    0 non-null      float64
#  29  comp1_rate_percent_diff      0 non-null      float64
#  30  comp2_rate                   450 non-null    float64
#  31  comp2_inv                    477 non-null    float64
#  32  comp2_rate_percent_diff      118 non-null    float64
#  33  comp3_rate                   400 non-null    float64
#  34  comp3_inv                    414 non-null    float64
#  35  comp3_rate_percent_diff      96 non-null     float64
#  36  comp4_rate                   87 non-null     float64
#  37  comp4_inv                    94 non-null     float64
#  38  comp4_rate_percent_diff      33 non-null     float64
#  39  comp5_rate                   518 non-null    float64
#  40  comp5_inv                    547 non-null    float64
#  41  comp5_rate_percent_diff      173 non-null    float64
#  42  comp6_rate                   81 non-null     float64
#  43  comp6_inv                    87 non-null     float64
#  44  comp6_rate_percent_diff      33 non-null     float64
#  45  comp7_rate                   105 non-null    float64
#  46  comp7_inv                    117 non-null    float64
#  47  comp7_rate_percent_diff      45 non-null     float64
#  48  comp8_rate                   438 non-null    float64
#  49  comp8_inv                    446 non-null    float64
#  50  comp8_rate_percent_diff      111 non-null    float64
#  51  click_bool                   1000 non-null   int64
#  52  gross_bookings_usd           27 non-null     float64
#  53  booking_bool                 1000 non-null   int64
# dtypes: float64(34), int64(19), object(1)
# memory usage: 422.0+ KB

# %%
# Correlation heatmap of dataset
def correlation_heatmap(df):
    sns.set(font_scale=1)
    fig = plt.figure()
    _ , ax = plt.subplots(figsize =(10, 10))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = colormap,
        square=True,
        cbar=False,
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':10 }
    )
    _.figure.tight_layout()

# %%
# Groups of attributes
visitor = list(range(3,6))
prop = list(range(6,17))
prop.remove(14)
srch = list(range(17,24))
target = list(range(51,54))
target.append(14)

correlation_heatmap(train.iloc[:,visitor+target])
plt.title('Visitor',fontdict = {'fontsize' : 16})

correlation_heatmap(train.iloc[:,prop+target])
plt.title('Property',fontdict = {'fontsize' : 16})

correlation_heatmap(train.iloc[:,srch+target])
plt.title('Search',fontdict = {'fontsize' : 16})

correlation_heatmap(train.iloc[:,target])
plt.title('Target',fontdict = {'fontsize' : 16})
# Out:
# Text(0.5, 1, 'Target')

# %%
print(train['click_bool'].value_counts())
print(train['booking_bool'].value_counts())
# Out:
# 0    957
# 1     43
# Name: click_bool, dtype: int64
# 0    973
# 1     27
# Name: booking_bool, dtype: int64

# %%
train.loc[train['click_bool'] == 1, 'position'].value_counts()
train.loc[train['click_bool'] == 1, 'position'].hist()
plt.ylabel('Counts'), plt.xlabel('position')
plt.title('Number of clicks per position (total = 43)')
plt.show()

train.loc[train['booking_bool'] == 1, 'position'].value_counts()
train.loc[train['booking_bool'] == 1, 'position'].hist()
plt.ylabel('Counts'), plt.xlabel('position')
plt.title('Number of bookings per position (total = 27)')
plt.show()
